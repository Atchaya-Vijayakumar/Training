# %%
dict={}
for _ in range(3):
    key=input("enter key value:")
    value=int(input("enter value:"))
    dict[key]=value
print("\nfinal dictonary:",dict)
# Out:
# enter key value: X
# enter value: 1
# enter key value: Y
# enter value: 2
# enter key value: Z
# enter value: 3
# final dictonary: {'X': 1, 'Y': 2, 'Z': 3}
