# %%
lst=[1,2,3]
print(lst)
# Out:
# [1, 2, 3]

# %%
lst.append(4)
print(lst)
# Out:
# [1, 2, 3, 4]

# %%
list=[2,4,6]
print(list)
# Out:
# [2, 4, 6]

# %%
lst=[1,3,5]
print(lst)
# Out:
# [1, 3, 5]

# %%
my_dic={"a":10,"b":20}
print(my_dic)
# Out:
# {'a': 10, 'b': 20}

# %%
my_dic["c"]=30
print(my_dic)
# Out:
# {'a': 10, 'b': 20, 'c': 30}
