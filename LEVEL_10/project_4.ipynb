# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
file_path = "House Price India.csv" 
data = pd.read_csv(file_path)
data.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810635  42491                   4                 2.50         2920
# 1  6762810998  42491                   5                 2.75         2910
# 2  6762812605  42491                   4                 2.50         3310
# 3  6762812919  42491                   3                 2.00         2710
# 4  6762813105  42491                   3                 2.50         2600
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      4000               1.5                   0                0
# 1      9480               1.5                   0                0
# 2     42998               2.0                   0                0
# 3      4500               1.5                   0                0
# 4      4750               1.0                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# ...

# %%
correlation_value = data['Price'].corr(data['living area'], method='pearson')
print(correlation_value)
# Out:
# 0.7122762653325179

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='living area', y='Price', data=data)
plt.title(f"Scatter Plot of Price vs. Living Area\nPearson Correlation: {correlation_value:.2f}")
plt.xlabel('Living Area (sq ft)')
plt.ylabel('Price (INR)')
plt.grid(True)
plt.show()

# %%
print(f"Pearson Correlation: {correlation_value:.2f}")
# Out:
# Pearson Correlation: 0.71
